# %%
################### DOCUMENTS
# http://naelshiab.com/quand-twitter-rencontre-python/
# https://marcobonzanini.com/2015/03/02/mining-twitter-data-with-python-part-1/
# https://marcobonzanini.com/2015/03/09/mining-twitter-data-with-python-part-2/
# https://marcobonzanini.com/2015/03/17/mining-twitter-data-with-python-part-3-term-frequencies/
# https://marcobonzanini.com/2015/03/23/mining-twitter-data-with-python-part-4-rugby-and-term-co-occurrences/
# https://marcobonzanini.com/2015/04/01/mining-twitter-data-with-python-part-5-data-visualisation-basics/
# https://marcobonzanini.com/2015/05/17/mining-twitter-data-with-python-part-6-sentiment-analysis-basics/
# https://marcobonzanini.com/2015/06/16/mining-twitter-data-with-python-and-js-part-7-geolocation-and-interactive-maps/

# %%
########################################################################################
######################### QUEL SCREEN TWITTER EST A ANALYSER ? #########################
########################################################################################
MonScreenName = 'equipedefrance'
Langue = 'french'

# %%
# IMPORT PANDAS
import pandas as pd
# IMPORT TWEEPY
import tweepy
# IMPORT JSON RE & STRING ...
import json
import re
import string
import operator 
from collections import Counter
# IMPORT EMOJI & EMOTICON'S
import emoji
# IMPORT NLTK
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
# Gestion configparser
import configparser

# %%
# Gestion de la configuration
config = configparser.ConfigParser()
config.read('../Configuration.conf')
# Out:
# ['../Configuration.conf']

# %%
# Obtention de mes identifiants Twitter
ma_consumer_key = config.get('Twitter', 'consumer_key')
ma_consumer_secret = config.get('Twitter', 'consumer_secret')
ma_Oauth_token = config.get('Twitter', 'Oauth_token')
ma_Oauth_token_secret = config.get('Twitter', 'Oauth_token_secret')

# %%
# IDENTIFICATION DE MON API TWITTER
auth = tweepy.OAuthHandler(ma_consumer_key, ma_consumer_secret)
auth.set_access_token(ma_Oauth_token, ma_Oauth_token_secret)
api = tweepy.API(auth)

# %%
# FONCTION OBTENTION TWEETS DANS DATAFRAME
def MaRechercheTweets(ScreenName):
    #Twitter only allows access to a users most recent 3240 tweets with this method
    #initialize a list to hold all the tweepy Tweets
    alltweets = []
    #make initial request for most recent tweets (200 is the maximum allowed count)
    new_tweets = api.user_timeline(screen_name = ScreenName, count = 200)
    #save most recent tweets
    alltweets.extend(new_tweets)
    #save the id of the oldest tweet less one
    oldest = alltweets[-1].id - 1
    #keep grabbing tweets until there are no tweets left to grab
    while len(new_tweets) > 0:
        #all subsiquent requests use the max_id param to prevent duplicates
        new_tweets = api.user_timeline(screen_name = ScreenName, count = 200, max_id = oldest)
        #save most recent tweets
        alltweets.extend(new_tweets)
        #update the id of the oldest tweet less one
        oldest = alltweets[-1].id - 1
        print ('... %s Tweets chargés' % (len(alltweets)))
    #transform the tweepy tweets into a 2D array
    #outtweets = [[tweet.id_str, tweet.created_at, tweet.text.encode("utf-8")] for tweet in alltweets]
    outtweets = [[tweet.id_str, tweet.created_at, tweet.text] for tweet in alltweets]
    return outtweets

# %%
# FONCTION DE TRAITEMENT DU TEXTE DES TWEETS
def MonTraitementTweets(MonTweet, lowercase=False):
    Tokens = tokenize(MonTweet) # FONCTION(S) Tokenize
    TokensEmojis = [Token for Token in ''.join(c for c in MonTweet if c in emoji.UNICODE_EMOJI)] # Emoji's
    TokensEmojisSens = [emoji.demojize(Token) for Token in TokensEmojis] # Emoji's (Sens)
    TokensURLs = [Token for Token in Tokens if Token.startswith('http')] # URL's
    TokensHastags = [Token for Token in Tokens if Token.startswith('#')] # Hastag's
    TokensMentions = [Token for Token in Tokens if Token.startswith('@')] # Mention's
    TokensRestants = [Token for Token in Tokens if Token not in TokensEmojis
                                                and Token not in TokensURLs
                                                and Token not in TokensHastags
                                                and Token not in TokensMentions]
    TokensRestants = [Token.lower() for Token in TokensRestants if Token not in Punctuation] # Punctuation 
    TokensRestants = [Token.lower() for Token in TokensRestants if Token not in StopWords] # Stopwords                
    return pd.Series([TokensRestants, TokensEmojis, TokensEmojisSens, TokensURLs, TokensHastags, TokensMentions])

# %%
# FONCTION TOKENIZE
def tokenize(s):
    return tokens_re.findall(s)

# %%
# GESTION DES EMOTICON's POUR TOKENIZE
emoticons_str = r"""
    (?:
        [:=;] # Eyes
        [oO\-]? # Nose (optional)
        [D\)\]\(\]/\\OpP] # Mouth
    )"""
emoticon_re = re.compile(r'^'+emoticons_str+'$', re.VERBOSE | re.IGNORECASE)

# %%
# GESTION REGEX POUR TOKENIZE
regex_str = [
    emoticons_str,
    r'<[^>]+>', # HTML tags
    r'(?:@[\w_]+)', # @-mentions
    r"(?:\#+[\w_]+[\w\'_\-]*[\w_]+)", # hash-tags
    r'http[s]?://(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', # URLs
    r'(?:(?:\d+,?)+(?:\.?\d+)?)', # numbers
    r"(?:[a-z][a-z'\-_]+[a-z])", # words with - and '
    r'(?:[\w_]+)', # other words
    r'(?:\S)' # anything else
]
tokens_re = re.compile(r'('+'|'.join(regex_str)+')', re.VERBOSE | re.IGNORECASE)

# %%
# GESTION DE LA PONCTUATION
Punctuation = list(string.punctuation) + ['“', '…', '”']

# %%
# GESTION DES STOPWORDS
if Langue == 'english':
    StopWords = stopwords.words(Langue) + ['rt', 'via']             # Pour l'anglais
if Langue == 'french':
    StopWords = stopwords.words(Langue) + ['rt', 'via', 'les']      # Pour le français

# %%
TweetsCherches = MaRechercheTweets(MonScreenName)
TweetsCherches_df = pd.DataFrame(TweetsCherches, columns = ['Tweet_Id', 'Tweet_Date', 'Tweet_Texte'])
# Out:
# ... 400 Tweets chargés
# ... 600 Tweets chargés
# ... 800 Tweets chargés
# ... 1000 Tweets chargés
# ... 1200 Tweets chargés
# ... 1400 Tweets chargés
# ... 1600 Tweets chargés
# ... 1800 Tweets chargés
# ... 2000 Tweets chargés
# ... 2200 Tweets chargés
# ... 2400 Tweets chargés
# ... 2600 Tweets chargés
# ... 2800 Tweets chargés
# ... 3000 Tweets chargés
# ... 3200 Tweets chargés
# ... 3210 Tweets chargés
# ... 3210 Tweets chargés

# %%
# TRAITEMENT DU TEXTE DES TWEETS
TweetsCherches_df[['Tokens', 'Emojis', 'SensEmojis', 'URLs', 'Hastags', 'Mentions']] = TweetsCherches_df.apply(lambda x: MonTraitementTweets(x['Tweet_Texte']), axis = 1)
TweetsCherches_df
# Out:
#                  Tweet_Id          Tweet_Date  \
# 0     1119643136215650310 2019-04-20 16:45:00
# 1     1119177316549050369 2019-04-19 09:54:00
# 2     1117784797353578496 2019-04-15 13:40:37
# 2     [corinne, diacre, communiquera, jeudi, 2, mai,...         []
# 3                          [’, championne, monde, 🇫, 🇷]  [🏆, 💪, 👊]
# 4       [’, championne, monde, bleus, remportent, 🇫, 🇷]  [🔥, 🏆, 💪]
# 5     [match, contre, l'argentine, 🇦, 🇷, a, moment, ...  [⭐, ⭐, 🎮]
# 6     [suivez, finale, ’, face, ’, argentine, direct...         []
# 7     [finale, coupe, monde, face, ’, argentine, ’, ...        [👊]
# 8                             [finale, coupe, monde, ’]        [👊]
# 9     [bleus, futsal, chauds, hier, victoire, 6, 0, ...  [🔥, 🔥, 🔥]
# 10                       [encore, petit, pont, sign, é]        [🔥]
# 11    [2, ️, ⃣, matchs, 2, ️, ⃣, victoires, 7, ️, ⃣,...         []
# 12    [question, importante, faut-il, être, fou, êtr...        [😜]
# 13    [3, gardiens, l'equipe, france, futsal, prépar...        [👊]
# 14    [guy, stéphan, l'adjoint, didier, deschamps, l...         []
# 15    [bon, anniversaire, fête, 32, ans, aujourd'hui...     [🤜, 🤛]
# 16                   [victoire, l'equipe, france, 4, 0]         []
# 17    [4, ème, but, l'equipe, france, val, érie, gau...         []
# 18    [15, 874, spectateurs, strasbourg, soir, encou...         []
# 19                                          [3, bleues]         []
# 20                      [doubl, é, delphine, cascarino]         []
# 21    [c'est, mi-temps, 1, 0, ️, delphine, cascarino...        [⚽]
# 22         [but, l'equipe, france, delphine, cascarino]         []
# 23                               [’, parti, 🇫, 🇷, 🇩, 🇰]         []
# 24    [derniers, ballons, avant, coup, ’, envoi, 🇫, ...         []
# 25    [place, ’, échauffement, bleues, coup, ’, envo...         []
# 26    [composition, bleues, affronter, danemark, 🇫, ...        [👊]
# 27    [grace, geyoro, évoque, rencontre, soir, prépa...         []
# 28    [bleues, stade, france, danemark, dès, 21, h00...         []
# 29    [vestiaire, place, france, danemark, dès, 21, ...         []
# ...                                                 ...        ...
# 3180                                [voici, nom, russe]         []
# 3181                                [voici, nom, russe]         []
# 3182                                [voici, nom, russe]         []
# 3183                                [voici, nom, russe]         []
# 3184                                [voici, nom, russe]         []
# 3185                                [voici, nom, russe]         []
# 3186                                [voici, nom, russe]         []
# 3187                                [voici, nom, russe]         []
# 3188                                [voici, nom, russe]         []
# 3189                                [voici, nom, russe]         []
# 3190                                [voici, nom, russe]         []
# 3191                                [voici, nom, russe]         []
# 3192                                [voici, nom, russe]         []
# 3193                                [voici, nom, russe]         []
# 3194                                [voici, nom, russe]         []
# 3195                                [voici, nom, russe]         []
# 3196                                [voici, nom, russe]         []
# 3197                                [voici, nom, russe]         []
# 3198                                [voici, nom, russe]         []
# 3199                                [voici, nom, russe]         []
# 3200                                [voici, nom, russe]         []
# 3201                                [voici, nom, russe]         []
# 3202                                [voici, nom, russe]         []
# 3203                                [voici, nom, russe]         []
# 3204                                [voici, nom, russe]         []
# 3205                                [voici, nom, russe]         []
# 3206                                [voici, nom, russe]         []
# 3207                                [voici, nom, russe]         []
# 3208                                [voici, nom, russe]         []
# 3209                                [voici, nom, russe]         []
#
#                                              SensEmojis  \
# 0                                                    []
# 1                   [:grinning_face_with_smiling_eyes:]
# 2                                                    []
# 3          [:trophy:, :flexed_biceps:, :oncoming_fist:]
# 4                   [:fire:, :trophy:, :flexed_biceps:]
# 5     [:white_medium_star:, :white_medium_star:, :vi...
# 6                                                    []
# 7                                     [:oncoming_fist:]
# 8                                     [:oncoming_fist:]
# 9                              [:fire:, :fire:, :fire:]
# 10                                             [:fire:]
# 11                                                   []
# 12                         [:winking_face_with_tongue:]
# 13                                    [:oncoming_fist:]
# 14                                                   []
# 15            [:right-facing_fist:, :left-facing_fist:]
# 16                                                   []
# 17                                                   []
# 18                                                   []
# 19                                                   []
# 20                                                   []
# 21                                      [:soccer_ball:]
# 22                                                   []
# 23                                                   []
# 24                                                   []
# 25                                                   []
# 26                                    [:oncoming_fist:]
# 27                                                   []
# 28                                                   []
# 29                                                   []
# ...                                                 ...
# 3180                                                 []
# 3181                                                 []
# 3182                                                 []
# 3183                                                 []
# 3184                                                 []
# 3185                                                 []
# 3186                                                 []
# 3187                                                 []
# 3188                                                 []
# 3189                                                 []
# 3190                                                 []
# 3191                                                 []
# 3192                                                 []
# 3193                                                 []
# 3194                                                 []
# 3195                                                 []
# 3196                                                 []
# 3197                                                 []
# 3198                                                 []
# 3199                                                 []
# 3200                                                 []
# 3201                                                 []
# 3202                                                 []
# 3203                                                 []
# 3204                                                 []
# 3205                                                 []
# 3206                                                 []
# 3207                                                 []
# 3208                                                 []
# 3209                                                 []
#
#                            URLs                       Hastags  \
# 0     [https://t.co/hNEdQDhHag]                            []
# 1     [https://t.co/L7GGCZXebS]                            []
# 2     [https://t.co/mFtZGmegAa]                            []
# 3     [https://t.co/HdDB2OIGTR]            [#FIFAeNationsCup]
# 4     [https://t.co/EtcFMpmG2S]            [#FIFAeNationsCup]
# 5                            []                            []
# 6     [https://t.co/H2CpDZR7WD]            [#FIFAeNationsCup]
# 7     [https://t.co/RNStqIZHZN]            [#FIFAeNationsCup]
# 8     [https://t.co/xPW7SJAkpa]            [#FIFAeNationsCup]
# 9     [https://t.co/1ZyKXpKlZw]                            []
# 10    [https://t.co/hplstNNuKQ]           [#FiersdetreBleues]
# 11    [https://t.co/q2e7ZfmePH]                            []
# 12                           []                            []
# 13    [https://t.co/gXYxxjnXqQ]                            []
# 14    [https://t.co/1lSphAx2Qm]                            []
# 15    [https://t.co/1GdXTLOya8]            [#FiersdetreBleus]
# 16    [https://t.co/gNvxR3pI6Y]  [#FRADAN, #FiersdetreBleues]
# 17    [https://t.co/e8i3reCP9j]  [#FRADAN, #FiersdetreBleues]
# 18    [https://t.co/nJkdOz7uN1]  [#FRADAN, #FiersdetreBleues]
# 19    [https://t.co/Cj65Cw734R]  [#FRADAN, #FiersdetreBleues]
# 20    [https://t.co/r2Jnd1CZkf]  [#FRADAN, #FiersdetreBleues]
# 21    [https://t.co/cX755h2nvW]  [#FRADAN, #FiersdetreBleues]
# 22    [https://t.co/RS6b08cMWJ]  [#FRADAN, #FiersdetreBleues]
# 23    [https://t.co/OpsRrq9FlU]  [#FRADAN, #FiersdetreBleues]
# 24    [https://t.co/UeQNyuFIdA]  [#FRADAN, #FiersdetreBleues]
# 25    [https://t.co/EJz56TP0vo]  [#FRADAN, #FiersdetreBleues]
# 26    [https://t.co/xueeZ2jYRw]  [#FRADAN, #FiersdetreBleues]
# 27    [https://t.co/TFEAeaR6ZB]           [#FiersdetreBleues]
# 28    [https://t.co/MFTksKcFDz]  [#FRADAN, #FiersdetreBleues]
# 29    [https://t.co/vIL13gQTmR]  [#FRADAN, #FiersdetreBleues]
# ...                         ...                           ...
# 3180                         []                            []
# 3181                         []                            []
# 3182                         []                            []
# 3183                         []                            []
# 3184                         []                            []
# 3185                         []                            []
# 3186                         []                            []
# 3187                         []                            []
# 3188                         []                            []
# 3189                         []                            []
# 3190                         []                            []
# 3191  [https://t.co/AabUUVbsdJ]                            []
# 3192                         []                            []
# 3193  [https://t.co/S0KE1YQBH5]                            []
# 3194                         []                            []
# 3195                         []                            []
# 3196                         []                            []
# 3197                         []                            []
# 3198                         []                            []
# 3199                         []                            []
# 3200                         []                            []
# 3201  [https://t.co/89agkBOcsi]                            []
# 3202                         []                            []
# 3203                         []                            []
# 3204  [https://t.co/LpoA5tmy5k]                            []
# 3205                         []                            []
# 3206                         []                            []
# 3207                         []                            []
# 3208                         []                            []
# 3209                         []                            []
#
#                                            Mentions
# 0     [@FFF, @AntoGriezmann, @nglkante, @samumtiti]
# 1                 [@FFF, @AntoGriezmann, @nglkante]
# 2                                                []
# 3                                  [@efootdefrance]
# 4                                  [@efootdefrance]
# 5                  [@efootdefrance, @MATUIDIBlaise]
# 6                                  [@efootdefrance]
# 7                                  [@efootdefrance]
# 8                                  [@efootdefrance]
# 9                                                []
# 10                                    [@AmelMajri7]
# 11                                               []
# 12                                               []
# 13                                               []
# 14                                               []
# 15                                 [@MATUIDIBlaise]
# 16                                               []
# 17                                 [@GauvinValerie]
# 18                                               []
# 19                                               []
# 20                                      [@delphsix]
# 21                                      [@delphsix]
# 22                                      [@delphsix]
# 23                                               []
# 24                                               []
# 25                                               []
# 26                                               []
# 27                                               []
# 28                                               []
# 29                                               []
# ...                                             ...
# 3180                                 [@UnRedDeviIs]
# 3181                                    [@__AykZ__]
# 3182                                  [@Bouvilleee]
# 3183                              [@AntoineAmbrosi]
# 3184                                    [@beligane]
# 3185                                    [@jbhayek8]
# 3186                                 [@RayaninhoDZ]
# 3187                               [@FabiGraphism4]
# 3188                               [@kevindu421200]
# 3189                                      [@vanb0x]
# 3190                               [@Lenny86457062]
# 3191                                    [@sim_nj22]
# 3192                                    [@taayiraa]
# 3193                                 [@MrCyri73420]
# 3194                                    [@NAABZ___]
# 3195                                [@WelcomemrBee]
# 3196                                 [@pantheon92i]
# 3197                                       [@elxrz]
# 3198                                [@rorofoucault]
# 3199                                 [@astrooworld]
# 3200                               [@paulbertholle]
# 3201                                   [@imadino26]
# 3202                                       [@16EPL]
# 3203                                   [@Oakenduck]
# 3204                                   [@Elbruneto]
# 3205                              [@MxtteoLeRetour]
# 3206                                  [@ch_lemaire]
# 3207                               [@frenchshygirl]
# 3208                               [@Phenomennnnnn]
# 3209                                      [@Dje_94]
#
# [3210 rows x 9 columns]

# %%
# ANALYSE DE L'ENSEMBLE DES TWEETS (MOTS UTILES)
Comptage = Counter()
TsLesTokens = []
for i in range (0, len(TweetsCherches_df)):
    TsLesTokens.extend(TweetsCherches_df['Tokens'][i])
Comptage.update(TsLesTokens)
print('********** ANALYSE DES TWEETS (MOTS UTILES)')
print(Comptage.most_common(20))
# Out:
# ********** ANALYSE DES TWEETS (MOTS UTILES)
# [('voici', 1778), ('russe', 1770), ('nom', 1769), ('🇷', 331), ('🇫', 301), ('france', 283), ('️', 282), ('’', 253), ('1', 199), ('é', 191), ('bleus', 168), ('monde', 146), ('match', 135), ('2', 126), ('0', 121), ('a', 117), ('ée', 110), ('înement', 98), ('face', 90), ('h00', 89)]

# %%
# ANALYSE DE L'ENSEMBLE DES MENTIONS (PERSONNES RE-TWEETEES)
Comptage = Counter()
TsLesTokens = []
for i in range (0, len(TweetsCherches_df)):
    TsLesTokens.extend(TweetsCherches_df['Mentions'][i])
Comptage.update(TsLesTokens)
print('********** ANALYSE DES MENTIONS (PERSONNES RE-TWEETEES)')
print(Comptage.most_common(20))
# Out:
# ********** ANALYSE DES MENTIONS (PERSONNES RE-TWEETEES)
# [('@AntoGriezmann', 59), ('@KMbappe', 50), ('@W9', 30), ('@samumtiti', 26), ('@equipedefrance', 26), ('@paulpogba', 24), ('@MATUIDIBlaise', 22), ('@BenPavard28', 22), ('@_OlivierGiroud_', 22), ('@kimpembe_3', 19), ('@nglkante', 18), ('@FFF', 17), ('@Dembouz', 17), ('@AreolaOfficiel', 16), ('@benmendy23', 16), ('@raphaelvarane', 14), ('@TF1', 14), ('@CorentinTolisso', 12), ('@EURO2020', 11), ('@M6', 10)]

# %%
# ANALYSE DE L'ENSEMBLE DES HASHTAGS (REFERENCES)
Comptage = Counter()
TsLesTokens = []
for i in range (0, len(TweetsCherches_df)):
    TsLesTokens.extend(TweetsCherches_df['Hastags'][i])
Comptage.update(TsLesTokens)
print('********** ANALYSE DES HASHTAGS (REFERENCES)')
print(Comptage.most_common(20))
# Out:
# ********** ANALYSE DES HASHTAGS (REFERENCES)
# [('#FiersdetreBleus', 508), ('#FRAURU', 67), ('#FRA', 54), ('#FRAISL', 51), ('#FRAALL', 51), ('#FRAARG', 45), ('#FiersdetreBleues', 43), ('#FRADAN', 37), ('#ALLFRA', 37), ('#FRACRO', 36), ('#FRABEL', 34), ('#PBSFRA', 32), ('#FRAPBS', 29), ('#MOLFRA', 23), ('#FRAJAP', 16), ('#Bleus', 15), ('#FRABRE', 13), ('#FRAMEX', 12), ('#FRAUSA', 10), ('#fiersdetrebleus', 9)]

# %%
# ANALYSE DE L'ENSEMBLE DES EMOJIS (LEUR SENS)
Comptage = Counter()
TsLesTokens = []
for i in range (0, len(TweetsCherches_df)):
    TsLesTokens.extend(TweetsCherches_df['SensEmojis'][i])
Comptage.update(TsLesTokens)
print('********** ANALYSE DES EMOJIS (LEUR SENS)')
print(Comptage.most_common(20))
# Out:
# ********** ANALYSE DES EMOJIS (LEUR SENS)
# [(':white_medium_star:', 130), (':fire:', 103), (':oncoming_fist:', 90), (':soccer_ball:', 76), (':right_arrow:', 74), (':flexed_biceps:', 55), (':raising_hands:', 51), (':VS_button:', 31), (':grinning_face_with_smiling_eyes:', 27), (':white_circle:', 27), (':blue_circle:', 25), (':television:', 24), (':party_popper:', 24), (':star-struck:', 24), (':red_circle:', 23), (':raised_fist:', 22), (':face_with_tears_of_joy:', 22), (':alarm_clock:', 20), (':clapping_hands:', 20), (':smiling_face_with_heart-eyes:', 17)]
